# %%
#Libraries
import matplotlib.pyplot as plt #plotting
import numpy as np
import matplotlib.pylab as pylab #plotting
import scipy.integrate as integrate #integrating
from numpy import sqrt, sin, cos, pi
from decimal import Decimal
from scipy.optimize import curve_fit


# Global Constants
k=1.38064852* 10**(-23) # boltzmann constant
sigma_coll    = 1.5*10**(-19)   

#formatting plots
pylab.rcParams['figure.figsize'] = (13,8)
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

plt.ylabel('Temperature (C)',fontsize=16)
plt.xlabel('Voltage (V)', fontsize=16)

Vnoz = np.array([22.3,17.1,14.2,20.1,18.4,30.6,21])
Tnoz = np.array([433,313,248,380,345,622,400])
Voven = np.array([6.65,3.62,5,4.12,6.03,13.06,6.86])
Toven = np.array([308,172,218,255,246,501,290])

lowV = 10
hghV = 35
lowV2 = 0
hghV2 = 15
steps = 100

def fit(x,m,b):
    return m*x + b

#print(curve_fit(fit,Vnoz,Tnoz))

newfit1 = np.linspace(lowV,hghV,steps)
newfit2 = np.linspace(lowV2,hghV2,steps)

#first bracket means the first array
#second bracket means the element in that array
m1 = curve_fit(fit,Vnoz,Tnoz)[0][0]
b1 = curve_fit(fit,Vnoz,Tnoz)[0][1]
m2 = curve_fit(fit,Voven,Toven)[0][0]
b2 = curve_fit(fit,Voven,Toven)[0][1]

plt.plot(Vnoz,Tnoz,'r.',label = 'Nozzle Data')
plt.plot(Voven,Toven,'b.',label='Oven Data')
plt.plot(newfit1, fit(newfit1,m1,b1),'r',label='Nozzle Curve fit')
plt.plot(newfit2, fit(newfit2,m2,b2),'b',label='Oven Linear Curve fit')
plt.legend(fontsize=14)
#**************************************************************
# Retrieving the data for a given temperature
#**************************************************************

# Finding temperature index, set your T_find to be the temperature you want the data for
# use the find variable as the index you want
T_find_noz = 525
V_find_noz = (T_find_noz-b1)/m1
print('Given Voltage for temperature of Nozzle:')
print(V_find_noz)

T_find_oven = 525
V_find_oven = (T_find_oven-b2)/m2
print('Given Voltage for temperature of Nozzle:')
print(V_find_oven)

pylab.savefig('TempvsVoltage_both.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# Given Voltage for temperature of Nozzle:
# 26.37717156962125
# Given Voltage for temperature of Nozzle:
# 13.882268275901154

# %%
#Libraries
import matplotlib.pyplot as plt #plotting
import numpy as np
import matplotlib.pylab as pylab #plotting
import scipy.integrate as integrate #integrating
from numpy import sqrt, sin, cos, pi
from decimal import Decimal
from scipy.optimize import curve_fit


# Global Constants
k=1.38064852* 10**(-23) # boltzmann constant
sigma_coll    = 1.5*10**(-19)   

#formatting plots
pylab.rcParams['figure.figsize'] = (13,8)
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

plt.ylabel('Temperature (C)',fontsize=16)
plt.xlabel('Voltage (V)', fontsize=16)

Vnoz = np.array([22.3,17.1,14.2,20.1,18.4,30.6,21])
Tnoz = np.array([433,313,248,380,345,622,400])
Voven = np.array([6.65,3.62,5,4.12,6.03,13.06,6.86])
Toven = np.array([308,172,218,255,246,501,290])

lowV = 10
hghV = 35
steps = 100

def fit(x,m,b):
    return m*x + b

#print(curve_fit(fit,Vnoz,Tnoz))

newfit = np.linspace(lowV,hghV,steps)

#first bracket means the first array
#second bracket means the element in that array
m = curve_fit(fit,Vnoz,Tnoz)[0][0]
b = curve_fit(fit,Vnoz,Tnoz)[0][1]


plt.plot(Vnoz,Tnoz,'r.',label = 'Nozzle Data')
#plt.plot(Voven,Toven,'b.',label='Oven Data')
plt.plot(newfit, fit(newfit,m,b),'r',label='Nozzle Curve fit')
plt.legend(fontsize=14)
#**************************************************************
# Retrieving the data for a given temperature
#**************************************************************

# Finding temperature index, set your T_find to be the temperature you want the data for
# use the find variable as the index you want
T_find_noz = 525
V_find_noz = (T_find_noz-b1)/m1
print('Given Voltage for temperature:')
print(V_find_noz)

pylab.savefig('TempvsVoltage_noz.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# Given Voltage for temperature:
# 26.37717156962125

# %%
#Libraries
import matplotlib.pyplot as plt #plotting
import numpy as np
import matplotlib.pylab as pylab #plotting
import scipy.integrate as integrate #integrating
from numpy import sqrt, sin, cos, pi
from decimal import Decimal
from scipy.optimize import curve_fit


# Global Constants
k=1.38064852* 10**(-23) # boltzmann constant
sigma_coll    = 1.5*10**(-19)   

#formatting plots
pylab.rcParams['figure.figsize'] = (13,8)
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

plt.ylabel('Temperature (C)',fontsize=16)
plt.xlabel('Voltage (V)', fontsize=16)

Vnoz = np.array([22.3,17.1,14.2,20.1,18.4,30.6,21])
Tnoz = np.array([433,313,248,380,345,622,400])
Voven = np.array([6.65,3.62,5,4.12,6.03,13.06,6.86])
Toven = np.array([308,172,218,255,246,501,290])


lowV = 10
hghV = 30
lowV2 = 0
hghV2 = 20
steps = 100

def fit(x,m,b):
    return m*x + b

#print(curve_fit(fit,Vnoz,Tnoz))

newfit1 = np.linspace(lowV,hghV,steps)
newfit2 = np.linspace(lowV2,hghV2,steps)

#first bracket means the first array
#second bracket means the element in that array
m1 = curve_fit(fit,Vnoz,Tnoz)[0][0]
b1 = curve_fit(fit,Vnoz,Tnoz)[0][1]
m2 = curve_fit(fit,Voven,Toven)[0][0]
b2 = curve_fit(fit,Voven,Toven)[0][1]

#plt.plot(Vnoz,Tnoz,'r.',label = 'Nozzle Data')
plt.plot(Voven,Toven,'b.',label='Oven Data')
#plt.plot(newfit, fit(newfit1,m1,b1),'r',label='Nozzle Curve fit')
plt.plot(newfit2, fit(newfit2,m2,b2),'b',label='Oven Linear Curve fit')
plt.legend(fontsize=14)



pylab.savefig('TempvsVoltage_oven.pdf', format='pdf', dpi=1000,bbox_inches='tight')
